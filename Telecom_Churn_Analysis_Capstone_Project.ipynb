# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashvin-Vargez/Telecom-Churn-Analysis-EDA-Project-/blob/main/Telecom_Churn_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.
#
# ## <b> Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention. </b>

# %%
#importing necessary libraries for data manipulation and visualization 
import numpy as np 
import pandas as pd 
import datetime 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# importing drive functionality to read files from google drive  
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#reading csv file and creating pandas dataframe using pd.read_csv
df_tel = pd.read_csv('/content/drive/MyDrive/Almabetter/Telecom Churn Analysis/Telecom Churn.csv')

# %%
#checking the created dataframe
df_tel.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
#checking the tail of the dataframe 
df_tel.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
#checking the shape of dataframe 
df_tel.shape
# Out:
# (3333, 20)

# %%
#getting an overview of the dataframe 
df_tel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
#checking characteristics of the dataframe 
df_tel.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
#creating a dataframe with data exculsively of churned customers and loyal customers
df_churn = df_tel[df_tel['Churn'] == True ] 
df_loyal = df_tel[df_tel['Churn']== False]

# %%
#checking created  churn dataframe 
df_churn
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3301    CA              84        415                 No              No
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#checking the newly created loyal dataframe
df_loyal
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#checking shapes of the newly created dataframes 
print ( f"The shape of churn dataframe is {df_churn.shape}. \n The shape of loyal database is { df_loyal.shape}.")
# Out:
# The shape of churn dataframe is (483, 20).
#  The shape of loyal database is (2850, 20).

# %%
#adding the number of rows of the two dataframes to confirm 
churn_no = df_churn.shape[0] 
loyal_no = df_loyal.shape[0]
total_no = df_tel.shape[0]
if churn_no + loyal_no == total_no:
  print ( "The rows in the two newly created dataframes add up to the rows of the original dataframe ")
# Out:
# The rows in the two newly created dataframes add up to the rows of the original dataframe

# %%
#calculating the percentage of the churned customers 
print( f"The percentage of customers churned is {round((churn_no/total_no)*100, 4)}.")
# Out:
# The percentage of customers churned is 14.4914.

# %%
#checking unique number of values in churn dataframe to check the states with highest churn rate 
df_churn['State'].value_counts()
# Out:
# NJ    18
# TX    18
# MD    17
# MI    16
# NY    15
# MN    15
# MT    14
# NV    14
# MS    14
# WA    14
# SC    14
# ME    13
# KS    13
# CT    12
# MA    11
# AR    11
# NC    11
# OR    11
# WV    10
# OH    10
# UT    10
# DE     9
# CA     9
# IN     9
# OK     9
# WY     9
# ID     9
# NH     9
# CO     9
# SD     8
# KY     8
# AL     8
# GA     8
# FL     8
# VT     8
# PA     8
# MO     7
# WI     7
# NM     6
# RI     6
# ND     6
# VA     5
# NE     5
# IL     5
# TN     5
# DC     5
# LA     4
# AZ     4
# AK     3
# IA     3
# HI     3
# Name: State, dtype: int64

# %%
# checking number of service calls made by the churned customers 
df_churn['Customer service calls'].unique()
# Out:
# array([4, 5, 1, 0, 3, 2, 7, 9, 6, 8])

# %%
# checking customers who have churned without making a customer service call 
df_no_call_churn = df_churn[df_churn['Customer service calls']== 0 ]
df_no_call_churn
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 41      MD             135        408                Yes             Yes
# 76      DC              82        415                 No              No
# 91      LA             155        415                 No              No
# 115     ME              36        510                Yes             Yes
# 156     OH              83        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3151    ME              56        408                 No              No
# 3189    WA              76        510                Yes              No
# 3191    CT              87        415                 No              No
# 3246    NC              77        408                Yes             Yes
# 3301    CA              84        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#binning into categories to classify and make comparisons 
# see which state, plan type, total day minutes, total day calls , charges etc
